# %%
import sys
sys.path.append('..')
sys.path.append('../..')
sys.path.append('../../..')

import os
os.chdir('../../data/GosaiMPRA')

from utils import *

# %%
df = pd.read_excel('./supp_materials/media-2.xlsx', sheet_name=0)

# %%
# for index, row in df.iterrows():
#     if row['Usage'] == 'MPRA experimental data used for Malinois training, validation, and testing':
#         url = row['Link']
#         command = f'wget {url}'
#         subprocess.run(command, shell=True)

# %%
import subprocess
from concurrent.futures import ThreadPoolExecutor

def download(url):
    subprocess.run(f'wget -c {url}', shell=True)

urls = df[df['Usage'] == 'MPRA experimental data used for Malinois training, validation, and testing']['Link']

with ThreadPoolExecutor(max_workers=16) as executor:
    executor.map(download, urls)
# Out:
# --2024-01-24 00:08:22--  https://www.encodeproject.org/files/ENCFF996ECA/@@download/ENCFF996ECA.tsv
# --2024-01-24 00:08:22--  https://www.encodeproject.org/files/ENCFF018AMJ/@@download/ENCFF018AMJ.tsv
# --2024-01-24 00:08:22--  https://www.encodeproject.org/files/ENCFF345ASG/@@download/ENCFF345ASG.tsv
# --2024-01-24 00:08:22--  https://www.encodeproject.org/files/ENCFF970OLE/@@download/ENCFF970OLE.tsv
# Resolving www.encodeproject.org (www.encodeproject.org)... --2024-01-24 00:08:22--  https://www.encodeproject.org/files/ENCFF318XMJ/@@download/ENCFF318XMJ.tsv
# Resolving www.encodeproject.org (www.encodeproject.org)... Resolving www.encodeproject.org (www.encodeproject.org)... --2024-01-24 00:08:22--  https://www.encodeproject.org/files/ENCFF358MBK/@@download/ENCFF358MBK.tsv
# 34.211.244.144
# Resolving www.encodeproject.org (www.encodeproject.org)... Connecting to www.encodeproject.org (www.encodeproject.org)|34.211.244.144|:443... 34.211.244.144
# ...
