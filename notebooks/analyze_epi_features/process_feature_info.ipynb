# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('../pretrained_models/Enformer/Enformer_ESM.xlsx', sheet_name='Supplementary Table 2')
df
# Out:
#       index  genome   identifier  \
# 0         0       0  ENCFF833POA
# 1         1       0  ENCFF110QGM
# 2         2       0  ENCFF880MKD
# 3         3       0  ENCFF463ZLQ
# 4         4       0  ENCFF890OGQ
# ...     ...     ...          ...
# 5308   5308       0    CNhs14239
# 5309   5309       0    CNhs14240
# 5310   5310       0    CNhs14241
# 5311   5311       0    CNhs14244
# 5312   5312       0    CNhs14245
#
#                                                    file  clip  scale sum_stat  \
# 0     /home/drk/tillage/datasets/human/dnase/encode/...    32      2     mean
# 1     /home/drk/tillage/datasets/human/dnase/encode/...    32      2     mean
# 2     /home/drk/tillage/datasets/human/dnase/encode/...    32      2     mean
# 3     /home/drk/tillage/datasets/human/dnase/encode/...    32      2     mean
# 4     /home/drk/tillage/datasets/human/dnase/encode/...    32      2     mean
# ...                                                 ...   ...    ...      ...
# ...

# %%
df[['assay', 'cell_type']] = df['target'].str.split('/', n=1, expand=True)
df = df[['identifier', 'assay', 'cell_type', 'target']]
df
# Out:
# /tmp/ipykernel_1804321/3212972716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['assay', 'cell_type']] = df['target'].str.split('/', n=1, expand=True)
#        identifier  assay                                          cell_type  \
# 0     ENCFF833POA  DNase  cerebellum male adult (27 years) and male adul...
# 1     ENCFF110QGM  DNase  frontal cortex male adult (27 years) and male ...
# 2     ENCFF880MKD  DNase                                            chorion
# 3     ENCFF463ZLQ  DNase  Ishikawa treated with 0.02% dimethyl sulfoxide...
# 4     ENCFF890OGQ  DNase                                            GM03348
# ...           ...    ...                                                ...
# ...

# %%
df.to_csv('data/enformer_info.csv', index=False)
