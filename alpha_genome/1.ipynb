# %%
import os
import pickle
import numpy as np
import pandas as pd
from alphagenome.models import dna_client
from tqdm import tqdm
from utils import *
# Out:
# /home/hxcai/anaconda3/envs/torch/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.27.2 is exactly one major version older than the runtime version 6.31.1 at alphagenome/protos/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /home/hxcai/anaconda3/envs/torch/lib/python3.10/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.27.2 is exactly one major version older than the runtime version 6.31.1 at alphagenome/protos/dna_model.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(

# %%
os.environ["GRPC_PROXY_EXP"] = "http://127.0.0.1:7897"
os.environ["http_proxy"] = "http://127.0.0.1:7897"
os.environ["https_proxy"] = "http://127.0.0.1:7897"

api_key = 'AIzaSyCH8xp8n5siM8N7G7-qgR7Xy4q0ektB03s'
dna_model = dna_client.create(api_key)

seqs = ['N'*2048]

outputs = dna_model.predict_sequences(
    seqs,
    requested_outputs=[dna_client.OutputType.DNASE, dna_client.OutputType.CHIP_HISTONE],
    ontology_terms=None,
    progress_bar=True,
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
outputs[0].dnase
# Out:
# TrackData(values=array([[0.001297  , 0.0014801 , 0.00357056, ..., 0.0011673 , 0.00085068,
#         0.00097656],
#        [0.00167084, 0.00139618, 0.00314331, ..., 0.00120544, 0.00085068,
#         0.0010376 ],
#        [0.00213623, 0.00143433, 0.00334167, ..., 0.00137329, 0.00102234,
#         0.00110626],
#        ...,
#        [0.00242615, 0.00163269, 0.00379944, ..., 0.00154877, 0.00115967,
#         0.00128937],
#        [0.0039978 , 0.00260925, 0.00585938, ..., 0.00263977, 0.00190735,
#         0.00213623],
#        [0.00512695, 0.00390625, 0.00830078, ..., 0.00421143, 0.00296021,
#         0.00331116]], dtype=float32), metadata=                         name strand Assay title  ontology_curie  \
# 0        CL:0000047 DNase-seq      .   DNase-seq      CL:0000047
# 1        CL:0000084 DNase-seq      .   DNase-seq      CL:0000084
# 2        CL:0000115 DNase-seq      .   DNase-seq      CL:0000115
# 3        CL:0000127 DNase-seq      .   DNase-seq      CL:0000127
# 4        CL:0000134 DNase-seq      .   DNase-seq      CL:0000134
# ..                        ...    ...         ...             ...
# 300  UBERON:0036149 DNase-seq      .   DNase-seq  UBERON:0036149
# 301  UBERON:8300001 DNase-seq      .   DNase-seq  UBERON:8300001
# 302  UBERON:8300002 DNase-seq      .   DNase-seq  UBERON:8300002
# 303  UBERON:8300003 DNase-seq      .   DNase-seq  UBERON:8300003
# 304  UBERON:8300004 DNase-seq      .   DNase-seq  UBERON:8300004
#
#             biosample_name                 biosample_type  \
# 0       neuronal stem cell  in_vitro_differentiated_cells
# 1                   T-cell                   primary_cell
# 2         endothelial cell  in_vitro_differentiated_cells
# 3                astrocyte                   primary_cell
# 4    mesenchymal stem cell  in_vitro_differentiated_cells
# ..                     ...                            ...
# 300        suprapubic skin                         tissue
# 301         right forelimb                         tissue
# 302          left forelimb                         tissue
# 303         right hindlimb                         tissue
# 304          left hindlimb                         tissue
#
#     biosample_life_stage data_source endedness  genetically_modified
# 0              embryonic      encode    single                 False
# 1                  adult      encode    paired                 False
# 2                  adult      encode    paired                 False
# 3                unknown      encode    single                 False
# 4              embryonic      encode    paired                 False
# ..                   ...         ...       ...                   ...
# 300                adult      encode    paired                 False
# 301            embryonic      encode    paired                 False
# 302            embryonic      encode    paired                 False
# 303            embryonic      encode    paired                 False
# 304            embryonic      encode    paired                 False
#
# [305 rows x 10 columns], resolution=1, interval=None, uns=None)

# %%
outputs[0].rna_seq
